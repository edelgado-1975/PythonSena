# %% [markdown]
# <a href="https://colab.research.google.com/github/edelgado-1975/PythonSena/blob/main/0_Fundamentos_del_lenguaje.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **PSEUDOCODIGO - PSEINT - PYTHON**

# %% [markdown]
# La comprensión de algoritmos es vital para programar eficientemente en Python y otros lenguajes. Los algoritmos proporcionan estructura lógica para resolver problemas, optimizar el rendimiento del programa y fomentar la creatividad. Python, siendo fácil de aprender, requiere sólidas bases en algoritmos para aprovechar su potencial. Los algoritmos eficientes permiten desarrollar soluciones rápidas y escalables, esenciales en un campo dinámico como la programación. Invertir en comprender y dominar los algoritmos establece una base sólida para una exitosa carrera en el desarrollo de software.

# %% [markdown]
# Hacer algoritmos primero en PSeInt antes de pasarlos a Python ofrece varios beneficios. PSeInt permite una representación más visual y simplificada de los algoritmos, lo que facilita la comprensión y depuración de errores. Además, al trabajar en PSeInt, los programadores pueden centrarse en la lógica del algoritmo sin preocuparse por la sintaxis específica del lenguaje. Esto les permite iterar rápidamente y experimentar con diferentes enfoques para resolver un problema. Una vez que el algoritmo funciona correctamente en PSeInt, trasladarlo a Python se vuelve más sencillo, ya que solo se requiere la conversión de la lógica al nuevo lenguaje.

# %% [markdown]
# **INSTALACION DE PSEINT**
#
# PSeInt es un entorno de desarrollo para aprender programación que está disponible de forma gratuita y se puede descargar desde su sitio web oficial. Aquí tienes los pasos básicos para instalar PSeInt:
#
# Puedes descargar PSeInt desde su sitio web oficial: PSeInt - https://pseint.sourceforge.net/.
#
# Pasos de Instalación:
#
# 1. Una vez en el sitio web oficial, busca la sección de descargas o simplemente haz clic en el enlace de descarga directa.
#
# 2. Dependiendo de tu sistema operativo, selecciona la versión adecuada para tu computadora (Windows, Linux o macOS).
#
# 3.  el archivo de instalación y ábrelo.
#
# 4. Sigue las instrucciones del asistente de instalación.
# Generalmente, es un proceso bastante sencillo y solo implica hacer clic en "Siguiente" o "Instalar" siguiendo las indicaciones.
#
# 5. Una vez completada la instalación, podrás ejecutar PSeInt desde tu menú de inicio (en Windows) o desde el lanzador de aplicaciones (en Linux o macOS).
#
# Uso inicial:
# Al abrir PSeInt, encontrarás un entorno de trabajo limpio con un editor de texto y varias opciones en la barra de herramientas, para comenzar a escribir un algoritmo, simplemente escribe tu código en el editor de texto, una vez que hayas escrito tu algoritmo, puedes ejecutarlo haciendo clic en el botón "Ejecutar" en la barra de herramientas o presionando la tecla F9.
#
# **Nota:** para configurarlo que nos deje trabajar super bien debemos tener en cuenta click en el menu configurar / opciones del lenguaje (perfiles) / seleccionamos la opcion Sena tadsi caqueta / cerramos todas las ventanas y reiniciamos la aplicacion.

# %% [markdown]
# 1.	Escribirun programa que calcule el cubo y el cuadrado de dos numeros.![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.	Escribir un programa que calcule el cociente y el residuo dados dos números enteros.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ahora si ajuste su cinturon de seguridad y a trabajar se dijo tome el ejemplo anterior y siga las indicaciones de su instructor.
#
# **ESTRUCTURA DE CONTROL SECUENCIAL**
#
# 3.	Escribir un programa que calcule el área y perímetro de un pentágono.
# 4.	Escribir un programa que realice la suma de dos números enteros
# 5.	Escribir un programa que calcule el cuadrado de 243
# 6.	Escribir un programa que calcule el perímetro y área de un rectángulo
# 7.	Escribir un programa que lea de teclado la marca y modelo de un auto e imprima en pantalla el modelo y la marca.
# 8.	Escribir un programa que calcule la hipotenusa de un triángulo rectángulo.
# 9.	Escribir un programa que calcula el porcentaje de una cantidad.
# 10. Escribir un programa que calcule el promedio de tres notas de un estudiante de programacion, (capture su nombre e imprimalo al terminar y entregar el resultado).
# 11. Escribir un programa que calcule al perímetro y área de un círculo dado su radio.
# 12. Escribir un programa que calcule el área de un triángulo dados su base y altura.
# 13. Escribir un programa que calcule el volumen de un cubo dado su lado.
# 14. Escribir un programa que convierta grados Fahrenheit a grados Celsius.
# 15. Escribir un programa que calcule el área de un rectángulo dados su base y altura.
# 16. Escribir un programa que convierta millas a kilómetros.
# Escribir un programa que calcule el promedio de cuatro números enteros.
# 17. Escribir un programa que calcule el perímetro de un cuadrado dado su lado.
# 18. Escribir un programa que calcule el área de un círculo dados su radio.
# 19. Escribir un programa que calcule el área de un trapecio dados sus dos bases y su altura.
# 20. Escribir un programa que convierta de dolares a pesos Colombianos.

# %% [markdown]
# **ESTRUCTURA DE CONTROL CONDICIONAL**
#
# 1.	Escribir un programa que indique cuál es el mayor de cuatro números enteros.
# 2.	Escribir un programa que indique si un número es divisible entre 14
# 3.	Escribir un programa que indique si un número es múltiplo de 6
# 4.	Escribir un programa que indique ni un número es par o impar.
# 5.	Escribir un programa que indique si la suma de dos valores es positiva, negativa o cero.
# 6.	Escribir un programa que indique si un número es divisible entre dos y cinco (a la vez).
# 7.	Escribir un programa que indique si una persona tiene sobrepeso ( si se considera que debe pesar el número de centímetros que mide menos 100 o menos) Los datos deben ser positivos.
# 8.	Escribir un programa que calcule el cambio que debe darse a un cliente
# 9.	Escribir un programa que indica si un número es divisible entre 14
# 10.	Escribir un programa que indica si un número es múltiplo de 6.
# 11.	Escribir un programa que despliegue el día de la semana dado un numero de día
# 12.	Escribir un programa que realice mediante un menú la suma, resta, multiplicación, división y potenciación de dos números
# 13.	Escribir un programa que calcule el área de un cuadrado, un rectángulo y un triángulo.

# %% [markdown]
# **ESTRUCTURA Y CONTROL REPETITIVO**
# 1.	Escribir un programa que calcule el más grande, el más pequeño y la media de N números.
# 2.	Escribir un programa que indica el número de dígitos que tiene una cantidad a la izquierda del punto decimal.
# 3.	Escribir un programa que sume la serie 3,6,9 hasta 99 y despliegue su resultado.
# 4.	Escribir un programa que imprima los impares del 7 al 51
# 5.	Escribir un programa que verifica si un dato ingresado por teclado corresponde a la contraseña 252525
# 6.	Escribir un programa que indica positivos y negativos de un conjunto de 25 datos (utilizar estructura se control para).
# 7.	Escribir un programa que imprima en pantalla los enteros del 1 al 30 con sus recíprocos.
# 8.	Escribir un programa que indique la cantidad de positivos y negativos de un conjunto de 25 números.

# %% [markdown]
# **ARREGLOS Y MODULOS**
#
# 1.	Escribir un programa que indique de almacene en un arreglo unidimensional 100 datos e indique cuántos elementos positivos hay en el mismo
# 2.	Escribir un programa que indique cuál es el elemento mayor y menor en un vector de N posiciones
# 3.	Escribir un programa que llena un vector con 0 en las posiciones pares y 1 en las impares.
# 4.	Escribir un programa que busque un número en un vector de 10 Posiciones e indique su posición.
# 5.	Escribir un programa que guarde las ventas de 10 cajeros por 180 días e indique qué cajero vendió más, el día de más ventas y el total de las mismas (ventas).
# 6.	Escribir un programa que guarde la presión de 30 personas por tres días e indique día que la persona tuvo mayor presión, menor presión.
# 7.	Escribir un programa que capture con número enteros una matriz de 10 X 10 y al final de cada renglón imprima la suma de sus elementos
# 8.	Escribir un programa que capture la producción de 2 plantas por siete días. Indique qué planta produjo más y qué día.
# 9.	Escribir un programa que coloque datos en la diagonal principal de una matriz de 3 X 3.
# 10.	Escribir un programa que indiquen los elementos mayor y menor en un arreglo de 10 posiciones
# 11.	Escribir un programa que lea un vector A de elementos. Debe crear dos nuevos vectores B y C, de tal manera que el vector B queden todos los números impares y en el vector C todos los múltiplos de 3. Al final debe imprimir los tres vectores.
# 12.	Escribir un programa que busque un número en un vector, que indique la posición en la que aparece y el número de veces que se repite.
# 13.	Escribir un programa que lea un vector A de 10 elementos que determine e emprima cuál es el mayor y en qué posición se encuentra y cuál es el menor y en qué posición se encuentra.
# 14.	Escribir un programa que llene una matriz de 10 X 10 con enteros, pase los elementos a un vector, los ordene y finalmente los regrese ordenados a la matriz.
# 15.	Escribir un programa modular que mediante un menú calcule el área de un triángulo, rectángulo y círculo.
# 16.	Escribir un programa modular que simule un cajero automático con las opciones de depósitos, retiros y ver saldo.
